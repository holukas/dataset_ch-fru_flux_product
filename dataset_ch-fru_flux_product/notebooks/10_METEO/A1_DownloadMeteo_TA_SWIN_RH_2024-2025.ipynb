# %% [markdown]
# <span style='font-size:24px; display:block;'>
# Download data from database (influxdb)
# </span>
#
# <span style='font-size:40px; display:block;'>
# <b>Download data for specific variables</b></br>
# </span>

# %% [markdown]
# ---
# **Author**: Lukas Hörtnagl
# **Last update**: 19 Mar 2025

# %% [markdown]
# # **Imports**

# %%
import warnings
from datetime import datetime
import dbc_influxdb as dbc
warnings.simplefilter("ignore")

# %% [markdown]
# </br>

# %% [markdown]
# # **Connect to database**

# %%
# Folder with database configurations
DIRCONF = r'F:\Sync\luhk_work\20 - CODING\22 - POET\configs'  
# Instantiate class
dbc = dbc.dbcInflux(dirconf=DIRCONF)
# Out:
# Reading configuration files was successful.
# Connection to database works.

# %% [markdown]
# </br>

# %% [markdown]
# # **Download from database**

# %%
# Settings
SITE = 'ch-fru'  # Site name
BUCKET = f'{SITE}_processed'
MEASUREMENTS = ['RH', 'TA', 'SW']  # Measurement name
FIELDS = ['RH_T1_2_1', 'TA_T1_2_1', 'SW_IN_T1_1_1']  # Variable name; InfluxDB stores variable names as '_field'
DATA_VERSION = ['meteoscreening_diive']

START = '2024-01-01 00:00:01'  # Download data starting with this date
STOP = '2026-01-01 00:00:01'  # Download data before this date (the stop date itself is not included)
TIMEZONE_OFFSET_TO_UTC_HOURS = 1  # Timezone, e.g. "1" is translated to timezone "UTC+01:00" (CET, winter time)

# Data download
data_simple, data_detailed, assigned_measurements = \
    dbc.download(
        bucket=BUCKET,
        measurements=MEASUREMENTS,
        fields=FIELDS,
        start=START,
        stop=STOP,
        timezone_offset_to_utc_hours=TIMEZONE_OFFSET_TO_UTC_HOURS,
        data_version=DATA_VERSION
)
# Out:
# DOWNLOADING
#     from bucket ch-fru_processed
#     variables ['RH_T1_2_1', 'TA_T1_2_1', 'SW_IN_T1_1_1']
#     from measurements ['RH', 'TA', 'SW']
#     from data version ['meteoscreening_diive']
#     between 2024-01-01 00:00:01 and 2026-01-01 00:00:01
#     with timezone offset to UTC of 1
# Using querystring:
# from(bucket: "ch-fru_processed") |> range(start: 2024-01-01T00:00:01+01:00, stop: 2026-01-01T00:00:01+01:00) |> filter(fn: (r) => r["_measurement"] == "RH" or r["_measurement"] == "TA" or r["_measurement"] == "SW") |> filter(fn: (r) => r["data_version"] == "meteoscreening_diive") |> filter(fn: (r) => r["_field"] == "RH_T1_2_1" or r["_field"] == "TA_T1_2_1" or r["_field"] == "SW_IN_T1_1_1") |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# Used querystring: from(bucket: "ch-fru_processed") |> range(start: 2024-01-01T00:00:01+01:00, stop: 2026-01-01T00:00:01+01:00) |> filter(fn: (r) => r["_measurement"] == "RH" or r["_measurement"] == "TA" or r["_measurement"] == "SW") |> filter(fn: (r) => r["data_version"] == "meteoscreening_diive") |> filter(fn: (r) => r["_field"] == "RH_T1_2_1" or r["_field"] == "TA_T1_2_1" or r["_field"] == "SW_IN_T1_1_1") |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# querystring was constructed from:
#     bucketstring: from(bucket: "ch-fru_processed")
#     rangestring: |> range(start: 2024-01-01T00:00:01+01:00, stop: 2026-01-01T00:00:01+01:00)
#     measurementstring: |> filter(fn: (r) => r["_measurement"] == "RH" or r["_measurement"] == "TA" or r["_measurement"] == "SW")
#     dataversionstring: |> filter(fn: (r) => r["data_version"] == "meteoscreening_diive")
#     fieldstring: |> filter(fn: (r) => r["_field"] == "RH_T1_2_1" or r["_field"] == "TA_T1_2_1" or r["_field"] == "SW_IN_T1_1_1")
#     pivotstring: |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# Download finished.
# Downloaded data for 3 variables:
# <-- RH_T1_2_1  (33865 records)  first date: 2024-01-01 00:30:00  last date: 2026-01-01 00:00:00
# <-- SW_IN_T1_1_1  (34647 records)  first date: 2024-01-01 00:30:00  last date: 2026-01-01 00:00:00
# <-- TA_T1_2_1  (33865 records)  first date: 2024-01-01 00:30:00  last date: 2026-01-01 00:00:00
# ========================================
# Fields in measurement RH of bucket ch-fru_processed:
# #1  ch-fru_processed  RH  RH
# #2  ch-fru_processed  RH  RH_EP
# #3  ch-fru_processed  RH  RH_T1_2_1
# Found 3 fields in measurement RH of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement TA of bucket ch-fru_processed:
# #1  ch-fru_processed  TA  TA_EP
# #2  ch-fru_processed  TA  TA_ERA
# #3  ch-fru_processed  TA  TA_F
# #4  ch-fru_processed  TA  TA_F_MDS
# #5  ch-fru_processed  TA  TA_F_MDS_QC
# #6  ch-fru_processed  TA  TA_F_QC
# #7  ch-fru_processed  TA  TA_T1_2_1
# #8  ch-fru_processed  TA  T_SONIC
# Found 8 fields in measurement TA of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement SW of bucket ch-fru_processed:
# #1  ch-fru_processed  SW  NIGHT
# #2  ch-fru_processed  SW  SW_IN_CORRECTED_T1_2_1
# #3  ch-fru_processed  SW  SW_IN_ERA
# #4  ch-fru_processed  SW  SW_IN_F
# #5  ch-fru_processed  SW  SW_IN_F_MDS
# #6  ch-fru_processed  SW  SW_IN_F_MDS_QC
# #7  ch-fru_processed  SW  SW_IN_F_QC
# #8  ch-fru_processed  SW  SW_IN_POT
# #9  ch-fru_processed  SW  SW_IN_T1_1_1
# #10  ch-fru_processed  SW  SW_IN_T1_2_1
# #11  ch-fru_processed  SW  SW_OUT
# #12  ch-fru_processed  SW  SW_OUT_T1_1_1
# #13  ch-fru_processed  SW  SW_OUT_T1_2_1
# Found 13 fields in measurement SW of bucket ch-fru_processed.
# ========================================

# %% [markdown]
# </br>

# %% [markdown]
# # **Plot downloaded data**

# %%
data_simple.plot(x_compat=True, figsize=(16, 6), title="Downloaded data", subplots=True);

# %% [markdown]
# </br>

# %% [markdown]
# # **Save to file**

# %%
data_simple
# Out:
#                      RH_T1_2_1  SW_IN_T1_1_1  TA_T1_2_1
# TIMESTAMP_END
# 2024-01-01 00:30:00  99.997990           0.0   0.063089
# 2024-01-01 01:00:00  98.689082           0.0   0.365761
# 2024-01-01 01:30:00  95.548050           0.0   0.326444
# 2024-01-01 02:00:00  89.946188           0.0   0.767750
# 2024-01-01 02:30:00  85.651175           0.0   1.136206
# ...                        ...           ...        ...
# 2025-12-31 22:00:00  95.027002           0.0  -8.169633
# 2025-12-31 22:30:00  95.338244           0.0  -8.388672
# 2025-12-31 23:00:00  92.821024           0.0  -8.424472
# 2025-12-31 23:30:00  92.261019           0.0  -8.464377
# 2026-01-01 00:00:00  90.188314           0.0  -8.569500
#
# [34648 rows x 3 columns]

# %%
data_simple.to_csv(r"A2_TA_SWIN_RH_2024-2025.csv")

# %% [markdown]
# </br>

# %% [markdown]
# # **End of notebook.**
# Congratulations, you reached the end of this notebook! Before you go let's store your finish time.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2026-01-20 21:47:21
