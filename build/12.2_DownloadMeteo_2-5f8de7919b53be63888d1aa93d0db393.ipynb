# %% [markdown]
# **notebook version**: `3` (4 Jul 2024)
# **new in this version**: added check if downloaded data is indeed in 30MIN time resolution
#
# - This notebook can be used to download data from the database `InfluxDB`
# - Data are stored to a `.csv` file in this folder

# %% [markdown]
# Data from the datbase, but from the old bucket `CH-CHA_processing`.

# %% [markdown]
# # **Auto-settings**

# %% [markdown]
# ## Data settings

# %%
DIRCONF = r'F:\Sync\luhk_work\20 - CODING\22 - POET\configs'
# DIRCONF = r'P:\Flux\RDS_calculations\_scripts\_configs\configs'  # Folder with configuration files: needed e.g. for connection to database
TIMEZONE_OFFSET_TO_UTC_HOURS = 1  # Timezone, e.g. "1" is translated to timezone "UTC+01:00" (CET, winter time)
REQUIRED_TIME_RESOLUTION = '30min'  # 30MIN time resolution

# %% [markdown]
# ## Imports

# %%
import importlib.metadata
from datetime import datetime

# %matplotlib inline
import seaborn as sns
from pathlib import Path
from diive.core.io.files import save_parquet

sns.set_theme('notebook')
from dbc_influxdb import dbcInflux
from diive.core.plotting.heatmap_datetime import HeatmapDateTime
import warnings

warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
version_dbc = importlib.metadata.version("dbc_influxdb")
print(f"dbc-influxdb version: v{version_dbc}")
dbc = dbcInflux(dirconf=DIRCONF)  # Connect to database
# Out:
# diive version: v0.87.0
# dbc-influxdb version: v0.13.1
# Reading configuration files was successful.
# Connection to database works.

# %% [markdown]
# </br>

# %% [markdown]
# # **DOWNLOAD** screened data from the database

# %%
# %%time
data_simple, data_detailed, assigned_measurements = dbc.download(
    bucket=f'ch-fru_processed',
    measurements=['G', 'TA', 'SW', 'PPFD', 'LW', 'RH', 'PA', 'SWC', 'TS', 'PREC', 'RH'],
    fields=[
        'G_GF1_0.03_1',
        'G_GF1_0.03_2',
        'G_GF1_0.03_3',
        'G_GF1_0.03_4',
        'G_GF1_0.06_1',
        'G_GF1_0.06_2',
        'LW_IN_T1_2_1',
        'LW_OUT_T1_2_1',
        'PPFD_IN_CORRECTED_T1_2_1',
        'PPFD_OUT_T1_2_1',
        'PREC_TOT_FIXED_M1_1_2',
        'PREC_TOT_M1_1_1',
        'RH_T1_2_1',
        'SW_IN_CORRECTED_T1_2_1',
        'SW_OUT_T1_2_1',
        'SWC_GF1_0.05_1',        
        'SWC_GF1_0.15_1',
        'SWC_GF1_0.1_2',
        'SWC_GF1_0.25_1',
        'SWC_GF1_0.2_2',
        'SWC_GF1_0.3_2',
        'SWC_GF1_0.4_1',
        'SWC_GF1_0.4_2',        
        'SWC_GF1_0.6_2',
        'SWC_GF1_0.75_1',
        'SWC_GF1_0.95_1',
        'SWC_GF1_1_2',
        'TA_T1_2_1',
        'TS_GF1_0.01_1',
        'TS_GF1_0.02_1',
        'TS_GF1_0.04_1',
        'TS_GF1_0.05_2',
        'TS_GF1_0.07_1',
        'TS_GF1_0.15_1',
        'TS_GF1_0.1_1',
        'TS_GF1_0.1_2',
        'TS_GF1_0.25_1',
        'TS_GF1_0.2_2',
        'TS_GF1_0.3_2',
        'TS_GF1_0.4_1',        
        'TS_GF1_0.5_2',
        'TS_GF1_0.95_1',
        'TS_GF1_1_2',        
    ],
    start='2005-01-01 00:00:01',  # Download data starting with this date (the start date itself IS included),
    stop='2021-01-01 00:00:01',  # Download data before this date (the stop date itself IS NOT included),
    timezone_offset_to_utc_hours=TIMEZONE_OFFSET_TO_UTC_HOURS,
    data_version='meteoscreening_mst'
)
# Out:
# DOWNLOADING
#     from bucket ch-fru_processed
#     variables ['G_GF1_0.03_1', 'G_GF1_0.03_2', 'G_GF1_0.03_3', 'G_GF1_0.03_4', 'G_GF1_0.06_1', 'G_GF1_0.06_2', 'LW_IN_T1_2_1', 'LW_OUT_T1_2_1', 'PPFD_IN_CORRECTED_T1_2_1', 'PPFD_OUT_T1_2_1', 'PREC_TOT_FIXED_M1_1_2', 'PREC_TOT_M1_1_1', 'RH_T1_2_1', 'SW_IN_CORRECTED_T1_2_1', 'SW_OUT_T1_2_1', 'SWC_GF1_0.05_1', 'SWC_GF1_0.15_1', 'SWC_GF1_0.1_2', 'SWC_GF1_0.25_1', 'SWC_GF1_0.2_2', 'SWC_GF1_0.3_2', 'SWC_GF1_0.4_1', 'SWC_GF1_0.4_2', 'SWC_GF1_0.6_2', 'SWC_GF1_0.75_1', 'SWC_GF1_0.95_1', 'SWC_GF1_1_2', 'TA_T1_2_1', 'TS_GF1_0.01_1', 'TS_GF1_0.02_1', 'TS_GF1_0.04_1', 'TS_GF1_0.05_2', 'TS_GF1_0.07_1', 'TS_GF1_0.15_1', 'TS_GF1_0.1_1', 'TS_GF1_0.1_2', 'TS_GF1_0.25_1', 'TS_GF1_0.2_2', 'TS_GF1_0.3_2', 'TS_GF1_0.4_1', 'TS_GF1_0.5_2', 'TS_GF1_0.95_1', 'TS_GF1_1_2']
#     from measurements ['G', 'TA', 'SW', 'PPFD', 'LW', 'RH', 'PA', 'SWC', 'TS', 'PREC', 'RH']
#     from data version ['meteoscreening_mst']
#     between 2005-01-01 00:00:01 and 2021-01-01 00:00:01
#     with timezone offset to UTC of 1
# Using querystring:
# from(bucket: "ch-fru_processed") |> range(start: 2005-01-01T00:00:01+01:00, stop: 2021-01-01T00:00:01+01:00) |> filter(fn: (r) => r["_measurement"] == "G" or r["_measurement"] == "TA" or r["_measurement"] == "SW" or r["_measurement"] == "PPFD" or r["_measurement"] == "LW" or r["_measurement"] == "RH" or r["_measurement"] == "PA" or r["_measurement"] == "SWC" or r["_measurement"] == "TS" or r["_measurement"] == "PREC" or r["_measurement"] == "RH") |> filter(fn: (r) => r["data_version"] == "meteoscreening_mst") |> filter(fn: (r) => r["_field"] == "G_GF1_0.03_1" or r["_field"] == "G_GF1_0.03_2" or r["_field"] == "G_GF1_0.03_3" or r["_field"] == "G_GF1_0.03_4" or r["_field"] == "G_GF1_0.06_1" or r["_field"] == "G_GF1_0.06_2" or r["_field"] == "LW_IN_T1_2_1" or r["_field"] == "LW_OUT_T1_2_1" or r["_field"] == "PPFD_IN_CORRECTED_T1_2_1" or r["_field"] == "PPFD_OUT_T1_2_1" or r["_field"] == "PREC_TOT_FIXED_M1_1_2" or r["_field"] == "PREC_TOT_M1_1_1" or r["_field"] == "RH_T1_2_1" or r["_field"] == "SW_IN_CORRECTED_T1_2_1" or r["_field"] == "SW_OUT_T1_2_1" or r["_field"] == "SWC_GF1_0.05_1" or r["_field"] == "SWC_GF1_0.15_1" or r["_field"] == "SWC_GF1_0.1_2" or r["_field"] == "SWC_GF1_0.25_1" or r["_field"] == "SWC_GF1_0.2_2" or r["_field"] == "SWC_GF1_0.3_2" or r["_field"] == "SWC_GF1_0.4_1" or r["_field"] == "SWC_GF1_0.4_2" or r["_field"] == "SWC_GF1_0.6_2" or r["_field"] == "SWC_GF1_0.75_1" or r["_field"] == "SWC_GF1_0.95_1" or r["_field"] == "SWC_GF1_1_2" or r["_field"] == "TA_T1_2_1" or r["_field"] == "TS_GF1_0.01_1" or r["_field"] == "TS_GF1_0.02_1" or r["_field"] == "TS_GF1_0.04_1" or r["_field"] == "TS_GF1_0.05_2" or r["_field"] == "TS_GF1_0.07_1" or r["_field"] == "TS_GF1_0.15_1" or r["_field"] == "TS_GF1_0.1_1" or r["_field"] == "TS_GF1_0.1_2" or r["_field"] == "TS_GF1_0.25_1" or r["_field"] == "TS_GF1_0.2_2" or r["_field"] == "TS_GF1_0.3_2" or r["_field"] == "TS_GF1_0.4_1" or r["_field"] == "TS_GF1_0.5_2" or r["_field"] == "TS_GF1_0.95_1" or r["_field"] == "TS_GF1_1_2") |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# Used querystring: from(bucket: "ch-fru_processed") |> range(start: 2005-01-01T00:00:01+01:00, stop: 2021-01-01T00:00:01+01:00) |> filter(fn: (r) => r["_measurement"] == "G" or r["_measurement"] == "TA" or r["_measurement"] == "SW" or r["_measurement"] == "PPFD" or r["_measurement"] == "LW" or r["_measurement"] == "RH" or r["_measurement"] == "PA" or r["_measurement"] == "SWC" or r["_measurement"] == "TS" or r["_measurement"] == "PREC" or r["_measurement"] == "RH") |> filter(fn: (r) => r["data_version"] == "meteoscreening_mst") |> filter(fn: (r) => r["_field"] == "G_GF1_0.03_1" or r["_field"] == "G_GF1_0.03_2" or r["_field"] == "G_GF1_0.03_3" or r["_field"] == "G_GF1_0.03_4" or r["_field"] == "G_GF1_0.06_1" or r["_field"] == "G_GF1_0.06_2" or r["_field"] == "LW_IN_T1_2_1" or r["_field"] == "LW_OUT_T1_2_1" or r["_field"] == "PPFD_IN_CORRECTED_T1_2_1" or r["_field"] == "PPFD_OUT_T1_2_1" or r["_field"] == "PREC_TOT_FIXED_M1_1_2" or r["_field"] == "PREC_TOT_M1_1_1" or r["_field"] == "RH_T1_2_1" or r["_field"] == "SW_IN_CORRECTED_T1_2_1" or r["_field"] == "SW_OUT_T1_2_1" or r["_field"] == "SWC_GF1_0.05_1" or r["_field"] == "SWC_GF1_0.15_1" or r["_field"] == "SWC_GF1_0.1_2" or r["_field"] == "SWC_GF1_0.25_1" or r["_field"] == "SWC_GF1_0.2_2" or r["_field"] == "SWC_GF1_0.3_2" or r["_field"] == "SWC_GF1_0.4_1" or r["_field"] == "SWC_GF1_0.4_2" or r["_field"] == "SWC_GF1_0.6_2" or r["_field"] == "SWC_GF1_0.75_1" or r["_field"] == "SWC_GF1_0.95_1" or r["_field"] == "SWC_GF1_1_2" or r["_field"] == "TA_T1_2_1" or r["_field"] == "TS_GF1_0.01_1" or r["_field"] == "TS_GF1_0.02_1" or r["_field"] == "TS_GF1_0.04_1" or r["_field"] == "TS_GF1_0.05_2" or r["_field"] == "TS_GF1_0.07_1" or r["_field"] == "TS_GF1_0.15_1" or r["_field"] == "TS_GF1_0.1_1" or r["_field"] == "TS_GF1_0.1_2" or r["_field"] == "TS_GF1_0.25_1" or r["_field"] == "TS_GF1_0.2_2" or r["_field"] == "TS_GF1_0.3_2" or r["_field"] == "TS_GF1_0.4_1" or r["_field"] == "TS_GF1_0.5_2" or r["_field"] == "TS_GF1_0.95_1" or r["_field"] == "TS_GF1_1_2") |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# querystring was constructed from:
#     bucketstring: from(bucket: "ch-fru_processed")
#     rangestring: |> range(start: 2005-01-01T00:00:01+01:00, stop: 2021-01-01T00:00:01+01:00)
#     measurementstring: |> filter(fn: (r) => r["_measurement"] == "G" or r["_measurement"] == "TA" or r["_measurement"] == "SW" or r["_measurement"] == "PPFD" or r["_measurement"] == "LW" or r["_measurement"] == "RH" or r["_measurement"] == "PA" or r["_measurement"] == "SWC" or r["_measurement"] == "TS" or r["_measurement"] == "PREC" or r["_measurement"] == "RH")
#     dataversionstring: |> filter(fn: (r) => r["data_version"] == "meteoscreening_mst")
#     fieldstring: |> filter(fn: (r) => r["_field"] == "G_GF1_0.03_1" or r["_field"] == "G_GF1_0.03_2" or r["_field"] == "G_GF1_0.03_3" or r["_field"] == "G_GF1_0.03_4" or r["_field"] == "G_GF1_0.06_1" or r["_field"] == "G_GF1_0.06_2" or r["_field"] == "LW_IN_T1_2_1" or r["_field"] == "LW_OUT_T1_2_1" or r["_field"] == "PPFD_IN_CORRECTED_T1_2_1" or r["_field"] == "PPFD_OUT_T1_2_1" or r["_field"] == "PREC_TOT_FIXED_M1_1_2" or r["_field"] == "PREC_TOT_M1_1_1" or r["_field"] == "RH_T1_2_1" or r["_field"] == "SW_IN_CORRECTED_T1_2_1" or r["_field"] == "SW_OUT_T1_2_1" or r["_field"] == "SWC_GF1_0.05_1" or r["_field"] == "SWC_GF1_0.15_1" or r["_field"] == "SWC_GF1_0.1_2" or r["_field"] == "SWC_GF1_0.25_1" or r["_field"] == "SWC_GF1_0.2_2" or r["_field"] == "SWC_GF1_0.3_2" or r["_field"] == "SWC_GF1_0.4_1" or r["_field"] == "SWC_GF1_0.4_2" or r["_field"] == "SWC_GF1_0.6_2" or r["_field"] == "SWC_GF1_0.75_1" or r["_field"] == "SWC_GF1_0.95_1" or r["_field"] == "SWC_GF1_1_2" or r["_field"] == "TA_T1_2_1" or r["_field"] == "TS_GF1_0.01_1" or r["_field"] == "TS_GF1_0.02_1" or r["_field"] == "TS_GF1_0.04_1" or r["_field"] == "TS_GF1_0.05_2" or r["_field"] == "TS_GF1_0.07_1" or r["_field"] == "TS_GF1_0.15_1" or r["_field"] == "TS_GF1_0.1_1" or r["_field"] == "TS_GF1_0.1_2" or r["_field"] == "TS_GF1_0.25_1" or r["_field"] == "TS_GF1_0.2_2" or r["_field"] == "TS_GF1_0.3_2" or r["_field"] == "TS_GF1_0.4_1" or r["_field"] == "TS_GF1_0.5_2" or r["_field"] == "TS_GF1_0.95_1" or r["_field"] == "TS_GF1_1_2")
#     pivotstring: |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# Download finished.
# Downloaded data for 43 variables:
# <-- G_GF1_0.03_1  (214688 records)  first date: 2005-07-29 14:00:00  last date: 2017-11-13 22:00:00
# <-- G_GF1_0.03_2  (214831 records)  first date: 2005-07-29 14:00:00  last date: 2017-11-13 22:00:00
# <-- G_GF1_0.03_3  (134509 records)  first date: 2006-07-21 12:30:00  last date: 2014-04-09 12:00:00
# <-- G_GF1_0.03_4  (134603 records)  first date: 2006-07-21 12:30:00  last date: 2014-04-09 12:00:00
# <-- G_GF1_0.06_1  (53507 records)  first date: 2017-11-20 17:00:00  last date: 2021-01-01 00:00:00
# <-- G_GF1_0.06_2  (28876 records)  first date: 2017-11-20 17:00:00  last date: 2021-01-01 00:00:00
# <-- LW_IN_T1_2_1  (263971 records)  first date: 2005-09-09 12:30:00  last date: 2021-01-01 00:00:00
# <-- LW_OUT_T1_2_1  (266174 records)  first date: 2005-07-26 11:30:00  last date: 2021-01-01 00:00:00
# <-- PPFD_IN_CORRECTED_T1_2_1  (266483 records)  first date: 2005-09-09 12:30:00  last date: 2021-01-01 00:00:00
# <-- PPFD_OUT_T1_2_1  (39804 records)  first date: 2017-12-01 08:00:00  last date: 2021-01-01 00:00:00
# <-- PREC_TOT_FIXED_M1_1_2  (17520 records)  first date: 2019-01-01 00:30:00  last date: 2020-01-01 00:00:00
# <-- PREC_TOT_M1_1_1  (261688 records)  first date: 2005-07-26 11:30:00  last date: 2021-01-01 00:00:00
# <-- RH_T1_2_1  (229677 records)  first date: 2005-07-26 11:30:00  last date: 2021-01-01 00:00:00
# <-- SW_IN_CORRECTED_T1_2_1  (264857 records)  first date: 2005-09-09 12:30:00  last date: 2021-01-01 00:00:00
# <-- SW_OUT_T1_2_1  (235361 records)  first date: 2005-09-09 12:30:00  last date: 2021-01-01 00:00:00
# <-- SWC_GF1_0.05_1  (268706 records)  first date: 2005-07-29 14:00:00  last date: 2021-01-01 00:00:00
# <-- TS_GF1_0.95_1  (267343 records)  first date: 2005-07-29 14:00:00  last date: 2021-01-01 00:00:00
# <-- TS_GF1_1_2  (52349 records)  first date: 2017-11-20 17:00:00  last date: 2021-01-01 00:00:00
# ========================================
# Fields in measurement G of bucket ch-fru_processed:
# #1  ch-fru_processed  G  G_F_MDS
# #2  ch-fru_processed  G  G_F_MDS_QC
# #3  ch-fru_processed  G  G_GF1_0.03_1
# #4  ch-fru_processed  G  G_GF1_0.03_2
# #5  ch-fru_processed  G  G_GF1_0.03_3
# #6  ch-fru_processed  G  G_GF1_0.03_4
# #7  ch-fru_processed  G  G_GF1_0.06_1
# #8  ch-fru_processed  G  G_GF1_0.06_2
# Found 8 fields in measurement G of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement TA of bucket ch-fru_processed:
# #1  ch-fru_processed  TA  TA_EP
# #2  ch-fru_processed  TA  TA_ERA
# #3  ch-fru_processed  TA  TA_F
# #4  ch-fru_processed  TA  TA_F_MDS
# #5  ch-fru_processed  TA  TA_F_MDS_QC
# #6  ch-fru_processed  TA  TA_F_QC
# #7  ch-fru_processed  TA  TA_T1_2_1
# #8  ch-fru_processed  TA  T_SONIC
# Found 8 fields in measurement TA of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement SW of bucket ch-fru_processed:
# #1  ch-fru_processed  SW  NIGHT
# #2  ch-fru_processed  SW  SW_IN_CORRECTED_T1_2_1
# #3  ch-fru_processed  SW  SW_IN_ERA
# #4  ch-fru_processed  SW  SW_IN_F
# #5  ch-fru_processed  SW  SW_IN_F_MDS
# #6  ch-fru_processed  SW  SW_IN_F_MDS_QC
# #7  ch-fru_processed  SW  SW_IN_F_QC
# #8  ch-fru_processed  SW  SW_IN_POT
# #9  ch-fru_processed  SW  SW_IN_T1_1_1
# #10  ch-fru_processed  SW  SW_IN_T1_2_1
# #11  ch-fru_processed  SW  SW_OUT
# #12  ch-fru_processed  SW  SW_OUT_T1_1_1
# #13  ch-fru_processed  SW  SW_OUT_T1_2_1
# Found 13 fields in measurement SW of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement PPFD of bucket ch-fru_processed:
# #1  ch-fru_processed  PPFD  PPFD_IN
# #2  ch-fru_processed  PPFD  PPFD_IN_CORRECTED_T1_2_1
# #3  ch-fru_processed  PPFD  PPFD_IN_T1_2_1
# #4  ch-fru_processed  PPFD  PPFD_OUT_T1_2_1
# Found 4 fields in measurement PPFD of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement LW of bucket ch-fru_processed:
# #1  ch-fru_processed  LW  LW_IN_ERA
# #2  ch-fru_processed  LW  LW_IN_F
# #3  ch-fru_processed  LW  LW_IN_F_MDS
# #4  ch-fru_processed  LW  LW_IN_F_MDS_QC
# #5  ch-fru_processed  LW  LW_IN_F_QC
# #6  ch-fru_processed  LW  LW_IN_JSB
# #7  ch-fru_processed  LW  LW_IN_JSB_ERA
# #8  ch-fru_processed  LW  LW_IN_JSB_F
# #9  ch-fru_processed  LW  LW_IN_JSB_F_QC
# #10  ch-fru_processed  LW  LW_IN_JSB_QC
# #11  ch-fru_processed  LW  LW_IN_T1_1_1
# #12  ch-fru_processed  LW  LW_IN_T1_2_1
# #13  ch-fru_processed  LW  LW_OUT_T1_1_1
# #14  ch-fru_processed  LW  LW_OUT_T1_2_1
# Found 14 fields in measurement LW of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement RH of bucket ch-fru_processed:
# #1  ch-fru_processed  RH  RH
# #2  ch-fru_processed  RH  RH_EP
# #3  ch-fru_processed  RH  RH_T1_2_1
# Found 3 fields in measurement RH of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement PA of bucket ch-fru_processed:
# #1  ch-fru_processed  PA  CUSTOM_AIR_P_MEAN
# #2  ch-fru_processed  PA  PA_AVG_T1_2.0_1
# #3  ch-fru_processed  PA  PA_EP
# #4  ch-fru_processed  PA  PA_ERA
# #5  ch-fru_processed  PA  PA_F
# #6  ch-fru_processed  PA  PA_F_QC
# Found 6 fields in measurement PA of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement SWC of bucket ch-fru_processed:
# #1  ch-fru_processed  SWC  SWC_F_MDS_1
# #2  ch-fru_processed  SWC  SWC_F_MDS_1_QC
# #3  ch-fru_processed  SWC  SWC_F_MDS_2
# #4  ch-fru_processed  SWC  SWC_F_MDS_2_QC
# #5  ch-fru_processed  SWC  SWC_F_MDS_3
# #6  ch-fru_processed  SWC  SWC_F_MDS_3_QC
# #7  ch-fru_processed  SWC  SWC_F_MDS_4
# #8  ch-fru_processed  SWC  SWC_F_MDS_4_QC
# #9  ch-fru_processed  SWC  SWC_F_MDS_5
# #10  ch-fru_processed  SWC  SWC_F_MDS_5_QC
# #11  ch-fru_processed  SWC  SWC_F_MDS_6
# #12  ch-fru_processed  SWC  SWC_F_MDS_6_QC
# #13  ch-fru_processed  SWC  SWC_GF1_0.05_1
# #14  ch-fru_processed  SWC  SWC_GF1_0.05_2
# #15  ch-fru_processed  SWC  SWC_GF1_0.15_1
# #16  ch-fru_processed  SWC  SWC_GF1_0.1_2
# #17  ch-fru_processed  SWC  SWC_GF1_0.25_1
# #18  ch-fru_processed  SWC  SWC_GF1_0.2_2
# #19  ch-fru_processed  SWC  SWC_GF1_0.3_2
# #20  ch-fru_processed  SWC  SWC_GF1_0.4_1
# #21  ch-fru_processed  SWC  SWC_GF1_0.4_2
# #22  ch-fru_processed  SWC  SWC_GF1_0.5_2
# #23  ch-fru_processed  SWC  SWC_GF1_0.6_2
# #24  ch-fru_processed  SWC  SWC_GF1_0.75_1
# #25  ch-fru_processed  SWC  SWC_GF1_0.75_2
# #26  ch-fru_processed  SWC  SWC_GF1_0.95_1
# #27  ch-fru_processed  SWC  SWC_GF1_1_2
# Found 27 fields in measurement SWC of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement TS of bucket ch-fru_processed:
# #1  ch-fru_processed  TS  TS_F_MDS_1
# #2  ch-fru_processed  TS  TS_F_MDS_10
# #3  ch-fru_processed  TS  TS_F_MDS_10_QC
# #4  ch-fru_processed  TS  TS_F_MDS_11
# #5  ch-fru_processed  TS  TS_F_MDS_11_QC
# #6  ch-fru_processed  TS  TS_F_MDS_12
# #7  ch-fru_processed  TS  TS_F_MDS_12_QC
# #8  ch-fru_processed  TS  TS_F_MDS_1_QC
# #9  ch-fru_processed  TS  TS_F_MDS_2
# #10  ch-fru_processed  TS  TS_F_MDS_2_QC
# #11  ch-fru_processed  TS  TS_F_MDS_3
# #12  ch-fru_processed  TS  TS_F_MDS_3_QC
# #13  ch-fru_processed  TS  TS_F_MDS_4
# #14  ch-fru_processed  TS  TS_F_MDS_4_QC
# #15  ch-fru_processed  TS  TS_F_MDS_5
# #16  ch-fru_processed  TS  TS_F_MDS_5_QC
# #17  ch-fru_processed  TS  TS_F_MDS_6
# #18  ch-fru_processed  TS  TS_F_MDS_6_QC
# #19  ch-fru_processed  TS  TS_F_MDS_7
# #20  ch-fru_processed  TS  TS_F_MDS_7_QC
# #21  ch-fru_processed  TS  TS_F_MDS_8
# #22  ch-fru_processed  TS  TS_F_MDS_8_QC
# #23  ch-fru_processed  TS  TS_F_MDS_9
# #24  ch-fru_processed  TS  TS_F_MDS_9_QC
# #25  ch-fru_processed  TS  TS_GF1_0.01_1
# #26  ch-fru_processed  TS  TS_GF1_0.02_1
# #27  ch-fru_processed  TS  TS_GF1_0.04_1
# #28  ch-fru_processed  TS  TS_GF1_0.05_2
# #29  ch-fru_processed  TS  TS_GF1_0.07_1
# #30  ch-fru_processed  TS  TS_GF1_0.15_1
# #31  ch-fru_processed  TS  TS_GF1_0.1_1
# #32  ch-fru_processed  TS  TS_GF1_0.1_2
# #33  ch-fru_processed  TS  TS_GF1_0.25_1
# #34  ch-fru_processed  TS  TS_GF1_0.2_2
# #35  ch-fru_processed  TS  TS_GF1_0.3_2
# #36  ch-fru_processed  TS  TS_GF1_0.4_1
# #37  ch-fru_processed  TS  TS_GF1_0.4_2
# #38  ch-fru_processed  TS  TS_GF1_0.5_2
# #39  ch-fru_processed  TS  TS_GF1_0.6_2
# #40  ch-fru_processed  TS  TS_GF1_0.75_2
# #41  ch-fru_processed  TS  TS_GF1_0.95_1
# #42  ch-fru_processed  TS  TS_GF1_1_2
# Found 42 fields in measurement TS of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement PREC of bucket ch-fru_processed:
# #1  ch-fru_processed  PREC  PREC
# #2  ch-fru_processed  PREC  PREC_ERA
# #3  ch-fru_processed  PREC  PREC_F
# #4  ch-fru_processed  PREC  PREC_F_QC
# #5  ch-fru_processed  PREC  PREC_RAIN_TOT_M1_1_1
# #6  ch-fru_processed  PREC  PREC_TOT_FIXED_M1_1_2
# #7  ch-fru_processed  PREC  PREC_TOT_GF1_1_1
# #8  ch-fru_processed  PREC  PREC_TOT_M1_1_1
# #9  ch-fru_processed  PREC  PREC_TOT_T1_0.5_1
# Found 9 fields in measurement PREC of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement RH of bucket ch-fru_processed:
# #1  ch-fru_processed  RH  RH
# #2  ch-fru_processed  RH  RH_EP
# #3  ch-fru_processed  RH  RH_T1_2_1
# Found 3 fields in measurement RH of bucket ch-fru_processed.
# ========================================
# CPU times: total: 2min 30s
# 2020-12-31 22:30:00           NaN           NaN           NaN           NaN     -6.946144     -8.768112    233.154740     272.127827                  0.201068              0.0                    NaN              0.0  53.403354       57.750986       48.888452  ...       1.618433            NaN       1.601306            NaN       1.631644       1.753187           NaN      1.654222       2.580290      2.216278      2.735056      3.162629      3.492722       4.508283    5.160667
# 2020-12-31 23:00:00           NaN           NaN           NaN           NaN     -6.934731     -8.742898    263.644370     279.590583                  0.140758              0.0                    NaN              0.0  55.342491       57.760390       48.891721  ...       1.616331            NaN       1.599003            NaN       1.628538       1.752199           NaN      1.651333       2.577460      2.214167      2.734944      3.159903      3.492111       4.507120    5.159500
# 2020-12-31 23:30:00           NaN           NaN           NaN           NaN     -6.920823     -8.713072    272.254680     284.593210                  0.003366              0.0                    NaN              0.0  56.130198       57.762787       48.899950  ...       1.616858            NaN       1.597786            NaN       1.626212       1.750983           NaN      1.652667       2.580575      2.217778      2.732833      3.159003      3.494889       4.503832    5.158611
# 2021-01-01 00:00:00           NaN           NaN           NaN           NaN     -6.902706     -8.686237    283.518120     291.797280                  0.056984              0.0                    NaN              0.0  51.911248       57.760481       48.883098  ...       1.617385            NaN       1.599373            NaN       1.626426       1.750348           NaN      1.653889       2.578568      2.211444      2.729889      3.157783      3.492667       4.503778    5.154278
#
# [269286 rows x 43 columns]

# %% [markdown]
# ## Plot downloaded data

# %%
data_simple.plot(subplots=True, x_compat=True, title="Data from database, quality-screened using diive", figsize=(20, 20));

# %% [markdown]
# </br>

# %% [markdown]
# # **SAVE TO FILE**

# %%
OUTNAME = "12.3_CH-CHA_DATABASE_meteo_2005-2020"
OUTPATH = r""
filepath = save_parquet(filename=OUTNAME, data=data_simple, outpath=OUTPATH)
# data_simple.to_csv(Path(OUTPATH) / f"{OUTNAME}.csv")
# Out:
# Saved file 12.3_CH-CHA_DATABASE_meteo_2005-2020.parquet (0.527 seconds).

# %% [markdown]
# </br>

# %% [markdown]
# ## Heatmaps

# %%
for col in data_simple.columns:
    series = data_simple[col]
    series.name = col
    HeatmapDateTime(series, figsize=(6, 9)).show()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\heatmap_base.py:208: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(facecolor='white', figsize=self.figsize)

# %% [markdown]
# </br>

# %% [markdown]
# # **Stats**

# %%
data_simple.describe()
# Out:
#         G_GF1_0.03_1   G_GF1_0.03_2   G_GF1_0.03_3   G_GF1_0.03_4  G_GF1_0.06_1  G_GF1_0.06_2   LW_IN_T1_2_1  LW_OUT_T1_2_1  PPFD_IN_CORRECTED_T1_2_1  PPFD_OUT_T1_2_1  PREC_TOT_FIXED_M1_1_2  PREC_TOT_M1_1_1      RH_T1_2_1  SWC_GF1_0.05_1  SWC_GF1_0.15_1  ...  TS_GF1_0.01_1  TS_GF1_0.02_1  TS_GF1_0.04_1  TS_GF1_0.05_2  TS_GF1_0.07_1  TS_GF1_0.15_1   TS_GF1_0.1_1  TS_GF1_0.1_2  TS_GF1_0.25_1  TS_GF1_0.2_2  TS_GF1_0.3_2   TS_GF1_0.4_1  TS_GF1_0.5_2  TS_GF1_0.95_1    TS_GF1_1_2
