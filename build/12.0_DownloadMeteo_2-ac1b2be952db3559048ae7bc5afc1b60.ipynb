# %% [markdown]
# **notebook version**: `3` (4 Jul 2024)
# **new in this version**: added check if downloaded data is indeed in 30MIN time resolution
#
# - This notebook can be used to download data from the database `InfluxDB`
# - Data are stored to a `.csv` file in this folder

# %% [markdown]
# Data from the datbase, but from the old bucket `CH-CHA_processing`.

# %% [markdown]
# # **Auto-settings**

# %% [markdown]
# ## Data settings

# %%
DIRCONF = r'F:\Sync\luhk_work\20 - CODING\22 - POET\configs'
# DIRCONF = r'P:\Flux\RDS_calculations\_scripts\_configs\configs'  # Folder with configuration files: needed e.g. for connection to database
TIMEZONE_OFFSET_TO_UTC_HOURS = 1  # Timezone, e.g. "1" is translated to timezone "UTC+01:00" (CET, winter time)
REQUIRED_TIME_RESOLUTION = '30min'  # 30MIN time resolution

# %% [markdown]
# ## Imports

# %%
import importlib.metadata
from datetime import datetime

# %matplotlib inline
import seaborn as sns
from pathlib import Path
from diive.core.io.files import save_parquet

sns.set_theme('notebook')
from dbc_influxdb import dbcInflux
from diive.core.plotting.heatmap_datetime import HeatmapDateTime
import warnings

warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
version_diive = importlib.metadata.version("diive")
print(f"diive version: v{version_diive}")
version_dbc = importlib.metadata.version("dbc_influxdb")
print(f"dbc-influxdb version: v{version_dbc}")
dbc = dbcInflux(dirconf=DIRCONF)  # Connect to database
# Out:
# diive version: v0.87.0
# dbc-influxdb version: v0.13.1
# Reading configuration files was successful.
# Connection to database works.

# %% [markdown]
# </br>

# %% [markdown]
# # **DOWNLOAD** screened data from the database

# %%
# %%time
data_simple, data_detailed, assigned_measurements = dbc.download(
    bucket=f'ch-fru_processed',
    measurements=['G', 'TA', 'SW', 'PPFD', 'LW', 'RH', 'PA', 'SWC', 'TS', 'PREC', 'RH'],
    fields=[
        'G_GF1_0.06_1',
        'G_GF1_0.06_2',
        'LW_IN_T1_1_1',
        'LW_OUT_T1_1_1',
        'PPFD_IN_T1_2_1',
        'PPFD_OUT_T1_2_1',
        'PREC_TOT_GF1_1_1',
        'PREC_TOT_T1_0.5_1',
        'RH_T1_2_1',
        'SW_IN_T1_1_1',
        'SW_OUT_T1_1_1',
        'SWC_GF1_0.05_1',
        'SWC_GF1_0.05_2',
        'SWC_GF1_0.15_1',
        'SWC_GF1_0.1_2',
        'SWC_GF1_0.25_1',
        'SWC_GF1_0.2_2',
        'SWC_GF1_0.3_2',
        'SWC_GF1_0.4_1',
        'SWC_GF1_0.4_2',
        'SWC_GF1_0.5_2',
        'SWC_GF1_0.6_2',
        'SWC_GF1_0.75_2',
        'SWC_GF1_0.95_1',
        'SWC_GF1_1_2',
        'TA_T1_2_1',
        'TS_GF1_0.01_1',
        'TS_GF1_0.04_1',
        'TS_GF1_0.05_2',
        'TS_GF1_0.07_1',
        'TS_GF1_0.15_1',
        'TS_GF1_0.1_1',
        'TS_GF1_0.1_2',
        'TS_GF1_0.25_1',
        'TS_GF1_0.2_2',
        'TS_GF1_0.3_2',
        'TS_GF1_0.4_1',
        'TS_GF1_0.4_2',
        'TS_GF1_0.5_2',
        'TS_GF1_0.6_2',
        'TS_GF1_0.75_2',        
        'TS_GF1_0.95_1',
        'TS_GF1_1_2',        
    ],
    start='2021-01-01 00:00:01',  # Download data starting with this date (the start date itself IS included),
    stop='2025-01-01 00:00:01',  # Download data before this date (the stop date itself IS NOT included),
    timezone_offset_to_utc_hours=TIMEZONE_OFFSET_TO_UTC_HOURS,
    data_version='meteoscreening_diive'
)
# Out:
# DOWNLOADING
#     from bucket ch-fru_processed
#     variables ['G_GF1_0.06_1', 'G_GF1_0.06_2', 'LW_IN_T1_1_1', 'LW_OUT_T1_1_1', 'PPFD_IN_T1_2_1', 'PPFD_OUT_T1_2_1', 'PREC_TOT_GF1_1_1', 'PREC_TOT_T1_0.5_1', 'RH_T1_2_1', 'SW_IN_T1_1_1', 'SW_OUT_T1_1_1', 'SWC_GF1_0.05_1', 'SWC_GF1_0.05_2', 'SWC_GF1_0.15_1', 'SWC_GF1_0.1_2', 'SWC_GF1_0.25_1', 'SWC_GF1_0.2_2', 'SWC_GF1_0.3_2', 'SWC_GF1_0.4_1', 'SWC_GF1_0.4_2', 'SWC_GF1_0.5_2', 'SWC_GF1_0.6_2', 'SWC_GF1_0.75_2', 'SWC_GF1_0.95_1', 'SWC_GF1_1_2', 'TA_T1_2_1', 'TS_GF1_0.01_1', 'TS_GF1_0.04_1', 'TS_GF1_0.05_2', 'TS_GF1_0.07_1', 'TS_GF1_0.15_1', 'TS_GF1_0.1_1', 'TS_GF1_0.1_2', 'TS_GF1_0.25_1', 'TS_GF1_0.2_2', 'TS_GF1_0.3_2', 'TS_GF1_0.4_1', 'TS_GF1_0.4_2', 'TS_GF1_0.5_2', 'TS_GF1_0.6_2', 'TS_GF1_0.75_2', 'TS_GF1_0.95_1', 'TS_GF1_1_2']
#     from measurements ['G', 'TA', 'SW', 'PPFD', 'LW', 'RH', 'PA', 'SWC', 'TS', 'PREC', 'RH']
#     from data version ['meteoscreening_diive']
#     between 2021-01-01 00:00:01 and 2025-01-01 00:00:01
#     with timezone offset to UTC of 1
# Using querystring:
# from(bucket: "ch-fru_processed") |> range(start: 2021-01-01T00:00:01+01:00, stop: 2025-01-01T00:00:01+01:00) |> filter(fn: (r) => r["_measurement"] == "G" or r["_measurement"] == "TA" or r["_measurement"] == "SW" or r["_measurement"] == "PPFD" or r["_measurement"] == "LW" or r["_measurement"] == "RH" or r["_measurement"] == "PA" or r["_measurement"] == "SWC" or r["_measurement"] == "TS" or r["_measurement"] == "PREC" or r["_measurement"] == "RH") |> filter(fn: (r) => r["data_version"] == "meteoscreening_diive") |> filter(fn: (r) => r["_field"] == "G_GF1_0.06_1" or r["_field"] == "G_GF1_0.06_2" or r["_field"] == "LW_IN_T1_1_1" or r["_field"] == "LW_OUT_T1_1_1" or r["_field"] == "PPFD_IN_T1_2_1" or r["_field"] == "PPFD_OUT_T1_2_1" or r["_field"] == "PREC_TOT_GF1_1_1" or r["_field"] == "PREC_TOT_T1_0.5_1" or r["_field"] == "RH_T1_2_1" or r["_field"] == "SW_IN_T1_1_1" or r["_field"] == "SW_OUT_T1_1_1" or r["_field"] == "SWC_GF1_0.05_1" or r["_field"] == "SWC_GF1_0.05_2" or r["_field"] == "SWC_GF1_0.15_1" or r["_field"] == "SWC_GF1_0.1_2" or r["_field"] == "SWC_GF1_0.25_1" or r["_field"] == "SWC_GF1_0.2_2" or r["_field"] == "SWC_GF1_0.3_2" or r["_field"] == "SWC_GF1_0.4_1" or r["_field"] == "SWC_GF1_0.4_2" or r["_field"] == "SWC_GF1_0.5_2" or r["_field"] == "SWC_GF1_0.6_2" or r["_field"] == "SWC_GF1_0.75_2" or r["_field"] == "SWC_GF1_0.95_1" or r["_field"] == "SWC_GF1_1_2" or r["_field"] == "TA_T1_2_1" or r["_field"] == "TS_GF1_0.01_1" or r["_field"] == "TS_GF1_0.04_1" or r["_field"] == "TS_GF1_0.05_2" or r["_field"] == "TS_GF1_0.07_1" or r["_field"] == "TS_GF1_0.15_1" or r["_field"] == "TS_GF1_0.1_1" or r["_field"] == "TS_GF1_0.1_2" or r["_field"] == "TS_GF1_0.25_1" or r["_field"] == "TS_GF1_0.2_2" or r["_field"] == "TS_GF1_0.3_2" or r["_field"] == "TS_GF1_0.4_1" or r["_field"] == "TS_GF1_0.4_2" or r["_field"] == "TS_GF1_0.5_2" or r["_field"] == "TS_GF1_0.6_2" or r["_field"] == "TS_GF1_0.75_2" or r["_field"] == "TS_GF1_0.95_1" or r["_field"] == "TS_GF1_1_2") |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# Used querystring: from(bucket: "ch-fru_processed") |> range(start: 2021-01-01T00:00:01+01:00, stop: 2025-01-01T00:00:01+01:00) |> filter(fn: (r) => r["_measurement"] == "G" or r["_measurement"] == "TA" or r["_measurement"] == "SW" or r["_measurement"] == "PPFD" or r["_measurement"] == "LW" or r["_measurement"] == "RH" or r["_measurement"] == "PA" or r["_measurement"] == "SWC" or r["_measurement"] == "TS" or r["_measurement"] == "PREC" or r["_measurement"] == "RH") |> filter(fn: (r) => r["data_version"] == "meteoscreening_diive") |> filter(fn: (r) => r["_field"] == "G_GF1_0.06_1" or r["_field"] == "G_GF1_0.06_2" or r["_field"] == "LW_IN_T1_1_1" or r["_field"] == "LW_OUT_T1_1_1" or r["_field"] == "PPFD_IN_T1_2_1" or r["_field"] == "PPFD_OUT_T1_2_1" or r["_field"] == "PREC_TOT_GF1_1_1" or r["_field"] == "PREC_TOT_T1_0.5_1" or r["_field"] == "RH_T1_2_1" or r["_field"] == "SW_IN_T1_1_1" or r["_field"] == "SW_OUT_T1_1_1" or r["_field"] == "SWC_GF1_0.05_1" or r["_field"] == "SWC_GF1_0.05_2" or r["_field"] == "SWC_GF1_0.15_1" or r["_field"] == "SWC_GF1_0.1_2" or r["_field"] == "SWC_GF1_0.25_1" or r["_field"] == "SWC_GF1_0.2_2" or r["_field"] == "SWC_GF1_0.3_2" or r["_field"] == "SWC_GF1_0.4_1" or r["_field"] == "SWC_GF1_0.4_2" or r["_field"] == "SWC_GF1_0.5_2" or r["_field"] == "SWC_GF1_0.6_2" or r["_field"] == "SWC_GF1_0.75_2" or r["_field"] == "SWC_GF1_0.95_1" or r["_field"] == "SWC_GF1_1_2" or r["_field"] == "TA_T1_2_1" or r["_field"] == "TS_GF1_0.01_1" or r["_field"] == "TS_GF1_0.04_1" or r["_field"] == "TS_GF1_0.05_2" or r["_field"] == "TS_GF1_0.07_1" or r["_field"] == "TS_GF1_0.15_1" or r["_field"] == "TS_GF1_0.1_1" or r["_field"] == "TS_GF1_0.1_2" or r["_field"] == "TS_GF1_0.25_1" or r["_field"] == "TS_GF1_0.2_2" or r["_field"] == "TS_GF1_0.3_2" or r["_field"] == "TS_GF1_0.4_1" or r["_field"] == "TS_GF1_0.4_2" or r["_field"] == "TS_GF1_0.5_2" or r["_field"] == "TS_GF1_0.6_2" or r["_field"] == "TS_GF1_0.75_2" or r["_field"] == "TS_GF1_0.95_1" or r["_field"] == "TS_GF1_1_2") |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# querystring was constructed from:
#     bucketstring: from(bucket: "ch-fru_processed")
#     rangestring: |> range(start: 2021-01-01T00:00:01+01:00, stop: 2025-01-01T00:00:01+01:00)
#     measurementstring: |> filter(fn: (r) => r["_measurement"] == "G" or r["_measurement"] == "TA" or r["_measurement"] == "SW" or r["_measurement"] == "PPFD" or r["_measurement"] == "LW" or r["_measurement"] == "RH" or r["_measurement"] == "PA" or r["_measurement"] == "SWC" or r["_measurement"] == "TS" or r["_measurement"] == "PREC" or r["_measurement"] == "RH")
#     dataversionstring: |> filter(fn: (r) => r["data_version"] == "meteoscreening_diive")
#     fieldstring: |> filter(fn: (r) => r["_field"] == "G_GF1_0.06_1" or r["_field"] == "G_GF1_0.06_2" or r["_field"] == "LW_IN_T1_1_1" or r["_field"] == "LW_OUT_T1_1_1" or r["_field"] == "PPFD_IN_T1_2_1" or r["_field"] == "PPFD_OUT_T1_2_1" or r["_field"] == "PREC_TOT_GF1_1_1" or r["_field"] == "PREC_TOT_T1_0.5_1" or r["_field"] == "RH_T1_2_1" or r["_field"] == "SW_IN_T1_1_1" or r["_field"] == "SW_OUT_T1_1_1" or r["_field"] == "SWC_GF1_0.05_1" or r["_field"] == "SWC_GF1_0.05_2" or r["_field"] == "SWC_GF1_0.15_1" or r["_field"] == "SWC_GF1_0.1_2" or r["_field"] == "SWC_GF1_0.25_1" or r["_field"] == "SWC_GF1_0.2_2" or r["_field"] == "SWC_GF1_0.3_2" or r["_field"] == "SWC_GF1_0.4_1" or r["_field"] == "SWC_GF1_0.4_2" or r["_field"] == "SWC_GF1_0.5_2" or r["_field"] == "SWC_GF1_0.6_2" or r["_field"] == "SWC_GF1_0.75_2" or r["_field"] == "SWC_GF1_0.95_1" or r["_field"] == "SWC_GF1_1_2" or r["_field"] == "TA_T1_2_1" or r["_field"] == "TS_GF1_0.01_1" or r["_field"] == "TS_GF1_0.04_1" or r["_field"] == "TS_GF1_0.05_2" or r["_field"] == "TS_GF1_0.07_1" or r["_field"] == "TS_GF1_0.15_1" or r["_field"] == "TS_GF1_0.1_1" or r["_field"] == "TS_GF1_0.1_2" or r["_field"] == "TS_GF1_0.25_1" or r["_field"] == "TS_GF1_0.2_2" or r["_field"] == "TS_GF1_0.3_2" or r["_field"] == "TS_GF1_0.4_1" or r["_field"] == "TS_GF1_0.4_2" or r["_field"] == "TS_GF1_0.5_2" or r["_field"] == "TS_GF1_0.6_2" or r["_field"] == "TS_GF1_0.75_2" or r["_field"] == "TS_GF1_0.95_1" or r["_field"] == "TS_GF1_1_2")
#     pivotstring: |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
# Download finished.
# Downloaded data for 43 variables:
# <-- G_GF1_0.06_1  (68884 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- G_GF1_0.06_2  (68870 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- LW_IN_T1_1_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- LW_OUT_T1_1_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- PPFD_IN_T1_2_1  (69646 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- PPFD_OUT_T1_2_1  (69646 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- PREC_TOT_GF1_1_1  (51430 records)  first date: 2021-11-25 16:00:00  last date: 2025-01-01 00:00:00
# <-- PREC_TOT_T1_0.5_1  (15767 records)  first date: 2021-01-01 00:30:00  last date: 2021-11-25 13:30:00
# <-- RH_T1_2_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SW_IN_T1_1_1  (69645 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SW_OUT_T1_1_1  (69646 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.05_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.15_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.25_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.4_1  (68869 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.95_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.05_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.1_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.2_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.3_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.4_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.5_2  (52822 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.6_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_0.75_2  (52857 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- SWC_GF1_1_2  (52350 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- TA_T1_2_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.01_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.04_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.07_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.1_1  (53138 records)  first date: 2021-11-25 16:00:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.15_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.25_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.4_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.95_1  (68905 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.1_2  (68600 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.2_2  (68600 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.3_2  (68600 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.5_2  (68564 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_1_2  (68042 records)  first date: 2021-01-01 00:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.05_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.4_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.6_2  (52858 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# <-- TS_GF1_0.75_2  (52857 records)  first date: 2021-12-16 15:30:00  last date: 2025-01-01 00:00:00
# ========================================
# Fields in measurement G of bucket ch-fru_processed:
# #1  ch-fru_processed  G  G_F_MDS
# #2  ch-fru_processed  G  G_F_MDS_QC
# #3  ch-fru_processed  G  G_GF1_0.03_1
# #4  ch-fru_processed  G  G_GF1_0.03_2
# #5  ch-fru_processed  G  G_GF1_0.03_3
# #6  ch-fru_processed  G  G_GF1_0.03_4
# #7  ch-fru_processed  G  G_GF1_0.06_1
# #8  ch-fru_processed  G  G_GF1_0.06_2
# Found 8 fields in measurement G of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement TA of bucket ch-fru_processed:
# #1  ch-fru_processed  TA  TA_EP
# #2  ch-fru_processed  TA  TA_ERA
# #3  ch-fru_processed  TA  TA_F
# #4  ch-fru_processed  TA  TA_F_MDS
# #5  ch-fru_processed  TA  TA_F_MDS_QC
# #6  ch-fru_processed  TA  TA_F_QC
# #7  ch-fru_processed  TA  TA_T1_2_1
# #8  ch-fru_processed  TA  T_SONIC
# Found 8 fields in measurement TA of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement SW of bucket ch-fru_processed:
# #1  ch-fru_processed  SW  NIGHT
# #2  ch-fru_processed  SW  SW_IN_CORRECTED_T1_2_1
# #3  ch-fru_processed  SW  SW_IN_ERA
# #4  ch-fru_processed  SW  SW_IN_F
# #5  ch-fru_processed  SW  SW_IN_F_MDS
# #6  ch-fru_processed  SW  SW_IN_F_MDS_QC
# #7  ch-fru_processed  SW  SW_IN_F_QC
# #8  ch-fru_processed  SW  SW_IN_POT
# #9  ch-fru_processed  SW  SW_IN_T1_1_1
# #10  ch-fru_processed  SW  SW_IN_T1_2_1
# #11  ch-fru_processed  SW  SW_OUT
# #12  ch-fru_processed  SW  SW_OUT_T1_1_1
# #13  ch-fru_processed  SW  SW_OUT_T1_2_1
# Found 13 fields in measurement SW of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement PPFD of bucket ch-fru_processed:
# #1  ch-fru_processed  PPFD  PPFD_IN
# #2  ch-fru_processed  PPFD  PPFD_IN_CORRECTED_T1_2_1
# #3  ch-fru_processed  PPFD  PPFD_IN_T1_2_1
# #4  ch-fru_processed  PPFD  PPFD_OUT_T1_2_1
# Found 4 fields in measurement PPFD of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement LW of bucket ch-fru_processed:
# #1  ch-fru_processed  LW  LW_IN_ERA
# #2  ch-fru_processed  LW  LW_IN_F
# #3  ch-fru_processed  LW  LW_IN_F_MDS
# #4  ch-fru_processed  LW  LW_IN_F_MDS_QC
# #5  ch-fru_processed  LW  LW_IN_F_QC
# #6  ch-fru_processed  LW  LW_IN_JSB
# #7  ch-fru_processed  LW  LW_IN_JSB_ERA
# #8  ch-fru_processed  LW  LW_IN_JSB_F
# #9  ch-fru_processed  LW  LW_IN_JSB_F_QC
# #10  ch-fru_processed  LW  LW_IN_JSB_QC
# #11  ch-fru_processed  LW  LW_IN_T1_1_1
# #12  ch-fru_processed  LW  LW_IN_T1_2_1
# #13  ch-fru_processed  LW  LW_OUT_T1_1_1
# #14  ch-fru_processed  LW  LW_OUT_T1_2_1
# Found 14 fields in measurement LW of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement RH of bucket ch-fru_processed:
# #1  ch-fru_processed  RH  RH
# #2  ch-fru_processed  RH  RH_EP
# #3  ch-fru_processed  RH  RH_T1_2_1
# Found 3 fields in measurement RH of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement PA of bucket ch-fru_processed:
# #1  ch-fru_processed  PA  CUSTOM_AIR_P_MEAN
# #2  ch-fru_processed  PA  PA_AVG_T1_2.0_1
# #3  ch-fru_processed  PA  PA_EP
# #4  ch-fru_processed  PA  PA_ERA
# #5  ch-fru_processed  PA  PA_F
# #6  ch-fru_processed  PA  PA_F_QC
# Found 6 fields in measurement PA of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement SWC of bucket ch-fru_processed:
# #1  ch-fru_processed  SWC  SWC_F_MDS_1
# #2  ch-fru_processed  SWC  SWC_F_MDS_1_QC
# #3  ch-fru_processed  SWC  SWC_F_MDS_2
# #4  ch-fru_processed  SWC  SWC_F_MDS_2_QC
# #5  ch-fru_processed  SWC  SWC_F_MDS_3
# #6  ch-fru_processed  SWC  SWC_F_MDS_3_QC
# #7  ch-fru_processed  SWC  SWC_F_MDS_4
# #8  ch-fru_processed  SWC  SWC_F_MDS_4_QC
# #9  ch-fru_processed  SWC  SWC_F_MDS_5
# #10  ch-fru_processed  SWC  SWC_F_MDS_5_QC
# #11  ch-fru_processed  SWC  SWC_F_MDS_6
# #12  ch-fru_processed  SWC  SWC_F_MDS_6_QC
# #13  ch-fru_processed  SWC  SWC_GF1_0.05_1
# #14  ch-fru_processed  SWC  SWC_GF1_0.05_2
# #15  ch-fru_processed  SWC  SWC_GF1_0.15_1
# #16  ch-fru_processed  SWC  SWC_GF1_0.1_2
# #17  ch-fru_processed  SWC  SWC_GF1_0.25_1
# #18  ch-fru_processed  SWC  SWC_GF1_0.2_2
# #19  ch-fru_processed  SWC  SWC_GF1_0.3_2
# #20  ch-fru_processed  SWC  SWC_GF1_0.4_1
# #21  ch-fru_processed  SWC  SWC_GF1_0.4_2
# #22  ch-fru_processed  SWC  SWC_GF1_0.5_2
# #23  ch-fru_processed  SWC  SWC_GF1_0.6_2
# #24  ch-fru_processed  SWC  SWC_GF1_0.75_1
# #25  ch-fru_processed  SWC  SWC_GF1_0.75_2
# #26  ch-fru_processed  SWC  SWC_GF1_0.95_1
# #27  ch-fru_processed  SWC  SWC_GF1_1_2
# Found 27 fields in measurement SWC of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement TS of bucket ch-fru_processed:
# #1  ch-fru_processed  TS  TS_F_MDS_1
# #2  ch-fru_processed  TS  TS_F_MDS_10
# #3  ch-fru_processed  TS  TS_F_MDS_10_QC
# #4  ch-fru_processed  TS  TS_F_MDS_11
# #5  ch-fru_processed  TS  TS_F_MDS_11_QC
# #6  ch-fru_processed  TS  TS_F_MDS_12
# #7  ch-fru_processed  TS  TS_F_MDS_12_QC
# #8  ch-fru_processed  TS  TS_F_MDS_1_QC
# #9  ch-fru_processed  TS  TS_F_MDS_2
# #10  ch-fru_processed  TS  TS_F_MDS_2_QC
# #11  ch-fru_processed  TS  TS_F_MDS_3
# #12  ch-fru_processed  TS  TS_F_MDS_3_QC
# #13  ch-fru_processed  TS  TS_F_MDS_4
# #14  ch-fru_processed  TS  TS_F_MDS_4_QC
# #15  ch-fru_processed  TS  TS_F_MDS_5
# #16  ch-fru_processed  TS  TS_F_MDS_5_QC
# #17  ch-fru_processed  TS  TS_F_MDS_6
# #18  ch-fru_processed  TS  TS_F_MDS_6_QC
# #19  ch-fru_processed  TS  TS_F_MDS_7
# #20  ch-fru_processed  TS  TS_F_MDS_7_QC
# #21  ch-fru_processed  TS  TS_F_MDS_8
# #22  ch-fru_processed  TS  TS_F_MDS_8_QC
# #23  ch-fru_processed  TS  TS_F_MDS_9
# #24  ch-fru_processed  TS  TS_F_MDS_9_QC
# #25  ch-fru_processed  TS  TS_GF1_0.01_1
# #26  ch-fru_processed  TS  TS_GF1_0.02_1
# #27  ch-fru_processed  TS  TS_GF1_0.04_1
# #28  ch-fru_processed  TS  TS_GF1_0.05_2
# #29  ch-fru_processed  TS  TS_GF1_0.07_1
# #30  ch-fru_processed  TS  TS_GF1_0.15_1
# #31  ch-fru_processed  TS  TS_GF1_0.1_1
# #32  ch-fru_processed  TS  TS_GF1_0.1_2
# #33  ch-fru_processed  TS  TS_GF1_0.25_1
# #34  ch-fru_processed  TS  TS_GF1_0.2_2
# #35  ch-fru_processed  TS  TS_GF1_0.3_2
# #36  ch-fru_processed  TS  TS_GF1_0.4_1
# #37  ch-fru_processed  TS  TS_GF1_0.4_2
# #38  ch-fru_processed  TS  TS_GF1_0.5_2
# #39  ch-fru_processed  TS  TS_GF1_0.6_2
# #40  ch-fru_processed  TS  TS_GF1_0.75_2
# #41  ch-fru_processed  TS  TS_GF1_0.95_1
# #42  ch-fru_processed  TS  TS_GF1_1_2
# Found 42 fields in measurement TS of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement PREC of bucket ch-fru_processed:
# #1  ch-fru_processed  PREC  PREC
# #2  ch-fru_processed  PREC  PREC_ERA
# #3  ch-fru_processed  PREC  PREC_F
# #4  ch-fru_processed  PREC  PREC_F_QC
# #5  ch-fru_processed  PREC  PREC_RAIN_TOT_M1_1_1
# #6  ch-fru_processed  PREC  PREC_TOT_FIXED_M1_1_2
# #7  ch-fru_processed  PREC  PREC_TOT_GF1_1_1
# #8  ch-fru_processed  PREC  PREC_TOT_M1_1_1
# #9  ch-fru_processed  PREC  PREC_TOT_T1_0.5_1
# Found 9 fields in measurement PREC of bucket ch-fru_processed.
# ========================================
# ========================================
# Fields in measurement RH of bucket ch-fru_processed:
# #1  ch-fru_processed  RH  RH
# #2  ch-fru_processed  RH  RH_EP
# #3  ch-fru_processed  RH  RH_T1_2_1
# Found 3 fields in measurement RH of bucket ch-fru_processed.
# ========================================
# CPU times: total: 59.9 s
# Wall time: 1min 14s

# %%
data_simple
# Out:
#                      G_GF1_0.06_1  G_GF1_0.06_2  LW_IN_T1_1_1  LW_OUT_T1_1_1  PPFD_IN_T1_2_1  PPFD_OUT_T1_2_1  PREC_TOT_GF1_1_1  PREC_TOT_T1_0.5_1  RH_T1_2_1  SWC_GF1_0.05_1  SWC_GF1_0.05_2  SWC_GF1_0.15_1  SWC_GF1_0.1_2  SWC_GF1_0.25_1  SWC_GF1_0.2_2  ...  TS_GF1_0.05_2  TS_GF1_0.07_1  TS_GF1_0.15_1  TS_GF1_0.1_1  TS_GF1_0.1_2  TS_GF1_0.25_1  TS_GF1_0.2_2  TS_GF1_0.3_2  TS_GF1_0.4_1  TS_GF1_0.4_2  TS_GF1_0.5_2  TS_GF1_0.6_2  TS_GF1_0.75_2  TS_GF1_0.95_1  TS_GF1_1_2
# TIMESTAMP_END                                                                                                                                                                                                                                                ...
# 2021-01-01 00:30:00     -6.887082     -8.630404    285.659340     292.033183             0.0              0.0               NaN                0.0  54.829798       57.757180             NaN       48.892675            NaN       52.328157            NaN  ...            NaN       1.628083       1.750629           NaN      1.652278       2.579931      2.206667      2.727833      3.158559           NaN      3.491056           NaN            NaN       4.505392    5.140111
# 2021-01-01 01:00:00     -6.881727     -8.593153    276.304473     289.757377             0.0              0.0               NaN                0.0  58.174412       57.748287             NaN       48.893477            NaN       52.325673            NaN  ...            NaN       1.622893       1.747853           NaN      1.651207       2.575691      2.203678      2.724253      3.152399           NaN      3.490172           NaN            NaN       4.501024    5.142586
# 2021-01-01 01:30:00     -6.860665     -8.571210    266.556937     282.779523             0.0              0.0               NaN                0.0  71.878856       57.746917             NaN       48.891679            NaN       52.325026            NaN  ...            NaN       1.622331       1.747667           NaN      1.650988       2.573988      2.200926      2.719136      3.154748           NaN      3.489630           NaN            NaN       4.498686    5.148580
# 2021-01-01 02:00:00     -6.850413     -8.579524    283.767490     288.579233             0.0              0.0               NaN                0.0  84.227086       57.744498             NaN       48.896227            NaN       52.322758            NaN  ...            NaN       1.621771       1.745108           NaN      1.650889       2.572263      2.199278      2.726000      3.152439           NaN      3.490111           NaN            NaN       4.497496    5.136444
# 2021-01-01 02:30:00     -6.840737     -8.568706    288.668837     292.348167             0.0              0.0               NaN                0.0  92.468086       57.743355             NaN       48.893252            NaN       52.326046            NaN  ...            NaN       1.619655       1.743779           NaN      1.651333       2.570895      2.196167      2.719111      3.150649           NaN      3.490333           NaN            NaN       4.494951    5.141333
# ...                           ...           ...           ...            ...             ...              ...               ...                ...        ...             ...             ...             ...            ...             ...            ...  ...            ...            ...            ...           ...           ...            ...           ...           ...           ...           ...           ...           ...            ...            ...         ...
# 2024-12-31 22:00:00     -6.896756     -6.284012    227.565077     265.189837             0.0              0.0               0.0                NaN  49.185175       61.780803       43.926217       51.267053      42.232317       50.217804      36.665633  ...       1.764472       2.165017       2.285103      2.001157      1.930993       2.943035      2.420493      2.846359      3.406129      3.293897      3.919832      4.228588       4.476450       4.700538    5.240322
# 2024-12-31 22:30:00     -6.897304     -6.290326    227.376887     264.182430             0.0              0.0               0.0                NaN  44.889381       61.790680       43.882013       51.275753      42.198453       50.223797      36.609347  ...       1.763824       2.161631       2.281670      1.997974      1.930993       2.945709      2.417234      2.842432      3.399110      3.297842      3.920494      4.229919       4.471778       4.700398    5.245044
# 2024-12-31 23:00:00     -6.897327     -6.346511    226.851997     266.966060             0.0              0.0               0.0                NaN  42.483432       61.796633       43.878760       51.282005      42.068270       50.232441      36.692087  ...       1.763824       2.159314       2.278250      1.995241      1.934887       2.945343      2.422450      2.841777      3.395493      3.292583      3.913211      4.228589       4.473780       4.699080    5.242346
# 2024-12-31 23:30:00     -6.886902     -6.386134    226.360590     265.374303             0.0              0.0               0.0                NaN  44.001726       61.796493       43.948093       51.284604      42.183543       50.236658      36.623340  ...       1.763824       2.159473       2.279412      1.993921      1.930344       2.942969      2.421144      2.847012      3.395651      3.294554      3.914532      4.230584       4.473113       4.699397    5.238300
# 2025-01-01 00:00:00     -6.885530     -6.358192    226.339197     263.930663             0.0              0.0               0.0                NaN  43.933636       61.789287       43.965850       51.279713      42.171563       50.233975      36.722370  ...       1.763824       2.160161       2.279148      1.993869      1.931644       2.941281      2.420494      2.842431      3.395173      3.294554      3.916520      4.230584       4.469777       4.699557    5.240327
#
# [69647 rows x 43 columns]

# %% [markdown]
# ## Plot downloaded data

# %%
data_simple.plot(subplots=True, x_compat=True, title="Data from database, quality-screened using diive", figsize=(20, 20));

# %% [markdown]
# </br>

# %% [markdown]
# # **SAVE TO FILE**

# %%
OUTNAME = "12.1_CH-CHA_DATABASE_meteo_2021-2024"
OUTPATH = r""
filepath = save_parquet(filename=OUTNAME, data=data_simple, outpath=OUTPATH)
# data_simple.to_csv(Path(OUTPATH) / f"{OUTNAME}.csv")
# Out:
# Saved file 12.1_CH-CHA_DATABASE_meteo_2021-2024.parquet (0.184 seconds).

# %% [markdown]
# </br>

# %% [markdown]
# ## Heatmaps

# %%
for col in data_simple.columns:
    series = data_simple[col]
    series.name = col
    HeatmapDateTime(series, figsize=(6, 9)).show()
# Out:
# F:\Sync\luhk_work\20 - CODING\21 - DIIVE\diive\diive\core\plotting\heatmap_base.py:208: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(facecolor='white', figsize=self.figsize)

# %% [markdown]
# </br>

# %% [markdown]
# # **Stats**

# %%
data_simple.describe()
# Out:
#        G_GF1_0.06_1  G_GF1_0.06_2  LW_IN_T1_1_1  LW_OUT_T1_1_1  PPFD_IN_T1_2_1  PPFD_OUT_T1_2_1  PREC_TOT_GF1_1_1  PREC_TOT_T1_0.5_1     RH_T1_2_1  SWC_GF1_0.05_1  SWC_GF1_0.05_2  SWC_GF1_0.15_1  SWC_GF1_0.1_2  SWC_GF1_0.25_1  SWC_GF1_0.2_2  ...  TS_GF1_0.05_2  TS_GF1_0.07_1  TS_GF1_0.15_1  TS_GF1_0.1_1  TS_GF1_0.1_2  TS_GF1_0.25_1  TS_GF1_0.2_2  TS_GF1_0.3_2  TS_GF1_0.4_1  TS_GF1_0.4_2  TS_GF1_0.5_2  TS_GF1_0.6_2  TS_GF1_0.75_2  TS_GF1_0.95_1    TS_GF1_1_2
# count  68884.000000  68870.000000  68905.000000   68905.000000    69646.000000     69646.000000      51430.000000       15767.000000  68905.000000    68905.000000    52858.000000    68905.000000   52858.000000    68905.000000   52858.000000  ...   52858.000000   68905.000000   68905.000000  53138.000000  68600.000000   68905.000000  68600.000000  68600.000000  68905.000000  52858.000000  68564.000000  52858.000000   52857.000000   68905.000000  68042.000000
# mean      -1.606143     -0.909837    311.527675     350.695220      296.197533        37.031474          0.096315           0.106590     81.823438       51.061598       32.736628       46.398400      32.024883       49.293914      28.888336  ...      10.058127      10.168224      10.038850      9.950559      9.821878      10.305508      9.860264      9.895499     10.075050     10.087594     10.180301     10.328652      10.067405      10.040207      9.873861
# std       13.717759     15.426299     46.159063      47.236782      492.751701       102.382423          0.505758           0.606911     17.375651        8.033006       14.032713        5.627493      11.356452        5.380692       7.253994  ...       6.861597       6.472353       6.113415      6.162990      6.408790       5.964642      6.050804      5.783886      5.506248      5.602243      5.365628      5.180444       4.903469       4.800138      4.498202
# min      -37.473936    -35.741029    172.159687     218.637617        0.000000         0.000000          0.000000           0.000000     19.417533       19.928273        0.424114       23.348222       3.945449       27.026562       9.614412  ...      -0.711102       0.193505       0.641624      0.339774      0.129228       1.234794      0.735325      1.182691      1.657271      1.630548      1.890222      2.444618       2.547015       2.701250      3.111858
# 25%       -9.881033    -10.026674    282.612863     312.732450        0.000000         0.000000          0.000000           0.000000     69.852581       47.661063       22.812528       45.387803      26.058417       46.913316      25.033123  ...       3.467755       3.972248       4.185394      4.033072      3.685446       4.504260      4.024031      4.245221      4.735123      4.681749      5.002063      5.352996       5.380666       5.391697      5.503020
# 50%       -5.853309     -5.714636    315.265027     346.520417        4.147746         0.383338          0.000000           0.000000     86.630203       52.532818       34.224525       47.597249      33.743733       50.612790      29.454865  ...      10.015113      10.046962       9.859647      9.973539      9.661942       9.978489      9.613876      9.647107      9.821896      9.825343      9.874203     10.155842       9.980164       9.876709      9.677145
# 75%        2.759617      3.682683    344.536853     380.282537      400.615648        37.915284          0.000000           0.000000     97.423519       56.596256       42.787673       49.702805      40.607025       52.767207      33.891664  ...      16.045933      16.310423      15.956209     15.870120     15.794349      16.197283     15.746922     15.568226     15.578696     15.414028     15.322980     15.217310      14.753333      14.784433     14.381056
# max       83.782477    118.972087    441.692857     508.376343     2309.779400      1469.430181         25.700000          38.600000     99.997990       63.955414       64.080120       55.502728      56.380660       57.736074      56.491203  ...      31.309233      25.774217      23.120488     23.397060     25.621843      21.717523     21.841180     20.767033     20.144492     20.210740     19.894070     19.433533      18.589800      18.466533     17.886210
#
# [8 rows x 43 columns]

# %% [markdown]
# </br>

# %% [markdown]
# # **End of notebook**.

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished. {dt_string}")
# Out:
# Finished. 2025-04-21 20:20:12

# %% [markdown]
# </br>
